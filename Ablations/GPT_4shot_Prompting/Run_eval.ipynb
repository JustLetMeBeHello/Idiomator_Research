# %%
# Stage 1 first
# !python gpt_baseline_stage1_4shot.py --test_path ../../idioms_structured/Splits/test.jsonl --train_path ../../idioms_structured/Splits/train.jsonl --output_dir models/gpt_stage1_4shot
# Out:
# Traceback (most recent call last):
#   File "/Users/shishirmaddineni/Desktop/Idiomator_Research/Research_And_Training/Ablations/GPT_4shot_Prompting/gpt_baseline_stage1_4shot.py", line 299, in <module>
#     main()
#   File "/Users/shishirmaddineni/Desktop/Idiomator_Research/Research_And_Training/Ablations/GPT_4shot_Prompting/gpt_baseline_stage1_4shot.py", line 217, in main
#     exemplar_pool = build_exemplar_pool(args.train_path, args.seed)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/shishirmaddineni/Desktop/Idiomator_Research/Research_And_Training/Ablations/GPT_4shot_Prompting/gpt_baseline_stage1_4shot.py", line 103, in build_exemplar_pool
#     records = [json.loads(l) for l in open(train_path, encoding='utf-8')]
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'train.jsonl'

# %%
# Stage 2 with Stage 1 gate
# !python gpt_baseline_stage2_4shot.py --test_path idioms_structured/Splits/test.jsonl --train_path idioms_structured/Splits/train.jsonl \
    --stage1_preds_path models/gpt_stage1_4shot/test_predictions.jsonl \
    --output_dir models/gpt_stage2_4shot

# %%
# Single-stage independently
# !python gpt_baseline_single_4shot.py --test_path idioms_structured/Splits/test.jsonl --train_path idioms_structured/Splits/train.jsonl --output_dir models/gpt_single_4shot
