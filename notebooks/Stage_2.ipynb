# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_15223/3329394316.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
import os
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['CD673448-D756-4F11-BCB5-47AD5E2D4F62_1_102_o.jpeg', '36147C1B-D54A-4FD9-97E9-9021114A9C01.mov', 'A1A01D68-D208-4F77-AC6D-E51F1B865F9F_1_102_a.jpeg', 'Colab Notebooks', 'Singing roadmap.gdoc', 'Untitled document (8).gdoc', 'Musical Conlang.gdoc', 'final_checkpoint', 'Untitled document (7).gdoc', 'Total flaws and holes to cover.gdoc', 'Language Learning plan.gdoc', 'Untitled document (6).gdoc', 'Silver Data creation.gdoc', 'Research Paper outline.gdoc', 'Idiomator.gdoc', 'Useful topics.gdoc', 'Steps for my AI room.gdoc', 'Untitled document (5).gdoc', 'Emails.gdoc', 'Untitled document (4).gdoc', 'Untitled document (3).gdoc', 'Telugu idioms.gdoc', 'First_idiomator_publicity_video.gdoc', 'Idiom project.gdoc', 'Physics frictional force.gsheet', '10 papers.gdoc', 'Gemini Gems', 'Untitled document (2).gdoc', 'Untitled document (1).gdoc', 'Untitled document.gdoc', 'Accomplishments.gdoc', 'Idiomator_Research']

# %%
# %%bash
# ls /content/drive/MyDrive/Idiomator_Research/
# Out:
# Ablations
# Collect_Results.py
# Google_Colab
# idioms_structured
# models
# __pycache__
# readme.md
# Requirements.txt
# Research_And_Training
# results
# Sampler.py
# Stage_1_training.py
# Stage_2.ipynb
# Stage_2_test.py
# Stage_2_training.py
# wandb

# %%
# Cell 2 — install dependencies
# !pip install transformers torch scikit-learn tqdm wandb optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 19.2 MB/s eta 0:00:00

# %%
# Cell 3 — wandb login
import os
os.environ['WANDB_API_KEY'] = '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'
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: 1356shishir (idiomator-app) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Cell 4 — verify GPU
# !nvidia-smi
# Out:
# Sun May 10 17:31:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Cell 5 — pull latest from GitHub
# !cd /content/drive/MyDrive/Idiomator_Research && git pull
# Out:
# error: Could not read 36322cd44eb402ca259a531e8de9af2863cde8b9
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 810 bytes | 1024 bytes/s, done.
# From https://github.com/JustLetMeBeHello/Idiomator_Research
#    23f1c85..bfdea11  main       -> origin/main
# Updating 23f1c85..bfdea11
# error: invalid object 100644 27245539cb93f00eb566146e2b3d191aa357afc0 for 'notebooks/colab/Sweep1.sh'
# Fast-forward
#  notebooks/colab/Optuna_Stage_2.py | 37 ++++++++++++++++++++++---------------
#  1 file changed, 22 insertions(+), 15 deletions(-)

# %%
import sys
sys.path.append('/content/drive/MyDrive/Idiomator_Research/Research_And_Training')

# %%
# %%bash
# cd /content/drive/MyDrive/Idiomator_Research/Research_And_Training
# export PYTHONPATH=/content/drive/MyDrive/Idiomator_Research:$PYTHONPATH
# pip install optuna -q
# python /content/drive/MyDrive/Idiomator_Research/notebooks/colab/Optuna_Stage_2.py \
#     --langs English Hindi Telugu \
#     --output_dir models/stage2_optuna \
#     --n_trials 30 \
#     --use_wandb
